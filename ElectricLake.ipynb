# %% [markdown]
# # Electric Lake
# Electric lake is a tool to extract and cache market data

# %%
import requests as re
import time, json, io
from os.path import exists
from datetime import timedelta
from datetime import datetime
from math import floor
import gc

# %%
import pandas as pd
import numpy as np

# %%
from multiprocessing.pool import ThreadPool
import multiprocessing as mp

# %% [markdown]
# ### Check for existence of the pickle

# %%
ticker_pickle_read = False
data_pickle_read = False
if exists("ticker_pickle.json"):
    ticker_pickle_read = True
    ticker_listing = json.load(io.open("ticker_pickle.json"))
    
if exists("data_pickle.json"):
    data_pickle_read = True
    ticker_db = json.load(io.open("data_pickle.json"))

# %%
if ticker_pickle_read:
    print("ticker_listing is an array with the following schema")
    print(ticker_listing['ticker' == 'A'])

if data_pickle_read:
    print("ticker_db has following schema")
    print("dict with tickers as keys")
    print("value is an array with")
    print("high, low, close, open, volume, vol-weighted price, num transactions, time represented as nansec date")
    # HACK: use agilent for last trade date, for simplicity
    print(pd.to_datetime(ticker_db['A'][-1]['t'], unit="ms" ))
    print((pd.to_datetime(ticker_db['A'][-1]['t'], unit="ms").to_pydatetime() + timedelta(days=1)).strftime("%Y-%m-%d")) # yyyy-mm-dd
    last_day_in_set = (pd.to_datetime(ticker_db['A'][-1]['t'], unit="ms").to_pydatetime() + timedelta(days=1)).strftime("%Y-%m-%d")
    current_date = datetime.today().strftime("%Y-%m-%d")
    print(current_date)
# Out:
# ticker_listing is an array with the following schema
# {'ticker': 'A', 'name': 'Agilent Technologies Inc.', 'market': 'stocks', 'locale': 'us', 'primary_exchange': 'XNYS', 'type': 'CS', 'active': True, 'currency_name': 'usd', 'cik': '0001090872', 'composite_figi': 'BBG000BWQYZ5', 'share_class_figi': 'BBG001SCTQY4', 'last_updated_utc': '2021-12-10T00:00:00Z'}
# ticker_db has following schema
# dict with tickers as keys
# value is an array with
# high, low, close, open, volume, vol-weighted price, num transactions, time represented as nansec date
# 2021-12-10 05:00:00
# 2021-12-11
# 2022-03-25

# %% [markdown]
# ### Get ticker listing; ~~pause for 12s~~

# %%
if not ticker_pickle_read:
    ticker_listing = []
    
    resp = re.get("https://api.polygon.io/v3/reference/tickers?active=true&sort=ticker&order=asc&limit=1000&apiKey=3Vkvu8G6DXjilpU75icHtY_wCwwOgOjh")
    print(resp)
    #time.sleep(12)

api_key_param = "&apiKey=SANITIZED"

# %%
if not ticker_pickle_read:
    print(dir(resp))
    print()
    print(resp.json()['next_url'] + api_key_param)

    ticker_listing += resp.json()['results']

    print("First set of tickers: ", end='')
    for t in ticker_listing[:10]:
        print(t['ticker'], end=', ')
    print()

# %% [markdown]
# ### Get all tickers

# %%
if not ticker_pickle_read:
    while resp.json().get('next_url') != None:
        # Get next url
        resp = re.get(resp.json()['next_url'] + api_key_param)

        time.sleep(12)

        ticker_listing += resp.json()['results']

        for t in resp.json()['results'][0:10]:
            print(t['ticker'], end=', ')
        print()

# %% [markdown]
# ### Write ticker symbols to disk

# %%
if not ticker_pickle_read:
    pck = io.open("ticker_pickle.json", "w")
    pck.write(json.dumps(ticker_listing))
    pck.close()

# %% [markdown]
# ### Display statistics about the types of tickers, listed exchanges, to narrow down our selection

# %%
ticker_stats = {'type' : {}, 'locale' : {}, 'primary_exchange' : {}}        
print(ticker_listing[0].keys())
for t in ticker_listing:
    for stat_k in ticker_stats.keys():
        if t.get(stat_k):
            if not t[stat_k] in ticker_stats[stat_k]:
                ticker_stats[stat_k] |= { t[stat_k] : 1 }
            else:
                ticker_stats[stat_k][t[stat_k]] += 1
        else:
            if not 'blank' in ticker_stats[stat_k]:
                ticker_stats[stat_k] |= { 'blank' : 1 }
            else:
                ticker_stats[stat_k]['blank'] += 1
                
ticker_stats
# Out:
# dict_keys(['ticker', 'name', 'market', 'locale', 'primary_exchange', 'type', 'active', 'currency_name', 'cik', 'composite_figi', 'share_class_figi', 'last_updated_utc'])
# {'type': {'CS': 6807,
#   'ETF': 2818,
#   'blank': 2045,
#   'UNIT': 783,
#   'WARRANT': 1020,
#   'ADRC': 533,
#   'PFD': 671,
#   'FUND': 472,
#   'RIGHT': 42,
#   'ETN': 100},
#  'locale': {'us': 13616, 'global': 1675},
#  'primary_exchange': {'XNYS': 4371,
#   'ARCX': 1956,
#   'XNAS': 6361,
#   'XASE': 351,
#   'BATS': 575,
#   'blank': 1677}}

# %% [markdown]
# ### Collect interesting tickers

# %%
interesting_ticker_symbols = []

for t in ticker_listing:
    if t.get('primary_exchange') and t.get('locale') == 'us':
        interesting_ticker_symbols += [t['ticker']]
        
print(interesting_ticker_symbols)
# Out:
# ['A', 'AA', 'AAA', 'AAAU', 'AAC', 'AAC.U', 'AAC.WS', 'AACG', 'AACI', 'AACIU', 'AACIW', 'AADI', 'AADR', 'AAIC', 'AAICpB', 'AAICpC', 'AAIN', 'AAL', 'AAMC', 'AAME', 'AAN', 'AAOI', 'AAON', 'AAP', 'AAPL', 'AAQC', 'AAQC.U', 'AAQC.WS', 'AAT', 'AATC', 'AAU', 'AAWW', 'AAXJ', 'AB', 'ABB', 'ABBV', 'ABC', 'ABCB', 'ABCL', 'ABCM', 'ABEO', 'ABEQ', 'ABEV', 'ABG', 'ABGI', 'ABIO', 'ABM', 'ABMD', 'ABNB', 'ABOS', 'ABR', 'ABRpD', 'ABRpE', 'ABRpF', 'ABSI', 'ABST', 'ABT', 'ABTX', 'ABUS', 'ABVC', 'AC', 'ACA', 'ACAD', 'ACAH', 'ACAHU', 'ACAHW', 'ACAQ', 'ACAQ.U', 'ACAQ.WS', 'ACB', 'ACBA', 'ACBAU', 'ACBAW', 'ACBI', 'ACC', 'ACCD', 'ACCO', 'ACDI.U', 'ACEL', 'ACER', 'ACES', 'ACET', 'ACEV', 'ACEVU', 'ACEVW', 'ACGL', 'ACGLN', 'ACGLO', 'ACH', 'ACHC', 'ACHL', 'ACHR', 'ACHR.WS', 'ACHV', 'ACI', 'ACII', 'ACII.U', 'ACII.WS', 'ACIO', 'ACIU', 'ACIW', 'ACKIT', 'ACKIU', 'ACKIW', 'ACLS', 'ACM', 'ACMR', 'ACN', 'ACNB', 'ACOR', 'ACP', 'ACPpA', 'ACQR', 'ACQRU', 'ACQRW', 'ACR', 'ACRE', 'ACRO', 'ACRO.U', 'ACRO.WS', 'ACRS', 'ACRX', 'ACRpC', 'ACRpD', 'ACSI', 'ACST', 'ACT', 'ACTD', 'ACTDU', 'ACTDW', 'ACTG', 'ACTV', 'ACU', 'ACV', 'ACVA', 'ACVF', 'ACWF', 'ACWI', 'ACWV', 'ACWX', 'ACXP', 'ACY', 'ADAG', 'ADALU', 'ADAP', 'ADBE', 'ADC', 'ADCT', 'ADCpA', 'ADER', 'ADERU', 'ADERW', 'ADES', 'ADEX', 'ADEX.U', 'ADEX.WS', 'ADFI', 'ADGI', 'ADI', 'ADIL', 'ADILW', 'ADIV', 'ADM', 'ADMA', 'ADME', 'ADMP', 'ADN', 'ADNT', 'ADNWW', 'ADOC', 'ADOCR', 'ADOCW', 'ADP', 'ADPT', 'ADRA', 'ADRA.U', 'ADRA.WS', 'ADRE', 'ADS', 'ADSK', 'ADT', 'ADTN', 'ADTX', 'ADUS', 'ADV', 'ADVM', 'ADVWW', 'ADX', 'ADXN', 'ADXS', 'AE', 'AEAC', 'AEACU', 'AEACW', 'AEAEU', 'AEE', 'AEF', 'AEFC', 'AEG', 'AEHA', 'AEHAU', 'AEHAW', 'AEHL', 'AEHR', 'AEI', 'AEIS', 'AEL', 'AELpA', 'AELpB', 'AEM', 'AEMB', 'AEMD', 'AENZ', 'AEO', 'AEP', 'AEPPL', 'AEPPZ', 'AER', 'AERC', 'AERI', 'AES', 'AESC', 'AESE', 'AESR', 'AEVA', 'AEVA.WS', 'AEY', 'AEYE', 'AEZS', 'AFACU', 'AFAQ', 'AFAQU', 'AFAQW', 'AFB', 'AFBI', 'AFCG', 'AFG', 'AFGB', 'AFGC', 'AFGD', 'AFGE', 'AFI', 'AFIB', 'AFIF', 'AFIN', 'AFINO', 'AFINP', 'AFK', 'AFL', 'AFLG', 'AFMC', 'AFMD', 'AFRM', 'AFSM', 'AFT', 'AFTR', 'AFTR.U', 'AFTR.WS', 'AFTY', 'AFYA', 'AG', 'AGAC', 'AGAC.U', 'AGAC.WS', 'AGBA', 'AGBAR', 'AGBAU', 'AGBAW', 'AGCB', 'AGCO', 'AGD', 'AGE', 'AGEN', 'AGFS', 'AGFY', 'AGG', 'AGGR', 'AGGRU', 'AGGRW', 'AGGY', 'AGI', 'AGIL', 'AGILW', 'AGIO', 'AGL', 'AGLE', 'AGM', 'AGM.A', 'AGMH', 'AGMpC', 'AGMpD', 'AGMpE', 'AGMpF', 'AGMpG', 'AGNC', 'AGNCM', 'AGNCN', 'AGNCO', 'AGNCP', 'AGNG', 'AGO', 'AGOV', 'AGOX', 'AGQ', 'AGR', 'AGRI', 'AGRIW', 'AGRO', 'AGRX', 'AGS', 'AGT', 'AGTC', 'AGTI', 'AGX', 'AGYS', 'AGZ', 'AGZD', 'AHCO', 'AHH', 'AHHX', 'AHHpA', 'AHI', 'AHLpC', 'AHLpD', 'AHLpE', 'AHPA', 'AHPAU', 'AHPAW', 'AHPI', 'AHT', 'AHTpD', 'AHTpF', 'AHTpG', 'AHTpH', 'AHTpI', 'AHYB', 'AI', 'AIA', 'AIC', 'AIEQ', 'AIF', 'AIG', 'AIGpA', 'AIH', 'AIHS', 'AIIQ', 'AIKI', 'AILG', 'AILV', 'AIM', 'AIMC', 'AIN', 'AINC', 'AINV', 'AIO', 'AIP', 'AIQ', 'AIR', 'AIRC', 'AIRG', 'AIRI', 'AIRR', 'AIRS', 'AIRT', 'AIRTP', 'AIT', 'AIV', 'AIZ', 'AIZN', 'AJG', 'AJRD', 'AJX', 'AJXA', 'AKA', 'AKAM', 'AKBA', 'AKIC', 'AKICU', 'AKICW', 'AKO.A', 'AKO.B', 'AKR', 'AKRO', 'AKTS', 'AKTX', 'AKU', 'AKUS', 'AKYA', 'AL', 'ALAC', 'ALACR', 'ALACU', 'ALACW', 'ALB', 'ALBO', 'ALC', 'ALCC', 'ALCO', 'ALDX', 'ALE', 'ALEC', 'ALEX', 'ALF', 'ALFA', 'ALFIW', 'ALG', 'ALGM', 'ALGN', 'ALGS', 'ALGT', 'ALHC', 'ALIM', 'ALINpA', 'ALINpB', 'ALINpE', 'ALIT', 'ALIT.WS', 'ALJJ', 'ALK', 'ALKS', 'ALKT', 'ALL', 'ALLE', 'ALLK', 'ALLO', 'ALLT', 'ALLY', 'ALLpB', 'ALLpG', 'ALLpH', 'ALLpI', 'ALNA', 'ALNY', 'ALORU', 'ALOT', 'ALPA', 'ALPAU', 'ALPAW', 'ALPN', 'ALPP', 'ALPpQ', 'ALRM', 'ALRN', 'ALRS', 'ALSN', 'ALT', 'ALTG', 'ALTGpA', 'ALTL', 'ALTM', 'ALTO', 'ALTR', 'ALTS', 'ALTU', 'ALTUU', 'ALTUW', 'ALTY', 'ALV', 'ALVR', 'ALX', 'ALXO', 'ALYA', 'ALZN', 'ALpA', 'AM', 'AMAL', 'AMAM', 'AMAO', 'AMAOU', 'AMAOW', 'AMAT', 'AMAX', 'AMBA', 'AMBC', 'AMBC.WS', 'AMBO', 'AMBP', 'AMBP.WS', 'AMC', 'AMCI', 'AMCIU', 'AMCIW', 'AMCR', 'AMCX', 'AMD', 'AME', 'AMED', 'AMEH', 'AMER', 'AMG', 'AMGN', 'AMH', 'AMHpF', 'AMHp ...

# %% [markdown]
# ### Collect dailies

# %%
if not data_pickle_read:    
    unformatted_agg_url = "https://api.polygon.io/v2/aggs/ticker/{ticker}/range/1/day/2000-12-10/2021-12-10?adjusted=true&sort=asc&limit=50000&apiKey=3Vkvu8G6DXjilpU75icHtY_wCwwOgOjh"
    ticker_db = {}
    for t in interesting_ticker_symbols:
        resp = re.get(unformatted_agg_url.format(ticker=t))
        print("ticker:", resp.json()['ticker'], end=' ')
        print("trading days:", resp.json()['resultsCount'])
        if resp.json()['resultsCount'] > 0:
            ticker_db[t] = resp.json()['results']
        else:
            ticker_db[t] = []


# temporarily disabled to test sanity of the merge code
if data_pickle_read:    
    unformatted_agg_url = "https://api.polygon.io/v2/aggs/ticker/{ticker}/range/1/day/{last_day_in_set}/{current_date}?adjusted=true&sort=asc&limit=50000&apiKey=3Vkvu8G6DXjilpU75icHtY_wCwwOgOjh"
    
    def _get_and_aggregate_ticker(ticker):
        local_resp = re.get(unformatted_agg_url.format(ticker=ticker,last_day_in_set=last_day_in_set,current_date=current_date))        
        print(local_resp.json()['ticker'], end=',')
        if local_resp.json()['resultsCount'] > 0:
            ticker_db[ticker] += local_resp.json()['results']
        
        if ticker=="QQQ":
            print(local_resp.json()['results'])
        
        del local_resp
        return True
    
    pool = ThreadPool(processes=8)
    
    res = [pool.apply_async(_get_and_aggregate_ticker,args=(t,)) for t in ticker_db.keys()]
    pool.close()
    pool.join()
# Out:
# AAC,AACG,AAC.WS,AAAU,AA,AAA,A,AAC.U,AACI,AACIU,AAICpB,AADI,AACIWAAIC,,AADRAAICpC,,AAME,AAIN,AAL,AAMC,AAON,AAOI,AAP,AAN,AAQC,AAPL,AAQC.UAAT,,AAQC.WS,AATC,AAU,AAWW,AAXJ,AB,ABB,ABC,ABCL,ABBV,ABCM,ABCB,ABEO,ABEQ,ABIO,ABEV,ABGI,ABM,ABG,ABMD,ABNBABOS,,ABR,ABRpD,ABRpE,ABRpF,ABSI,ABST,ABTXABT,,ABUSABVC,,AC,ACA,ACAD,ACAH,ACAHW,ACAQ.WS,ACAHU,ACAQ.U,ACAQ,ACB,ACBA,ACBAU,ACBAW,ACC,ACBI,ACCDACCO,,ACDI.U,ACEL,ACER,ACET,ACES,ACGL,ACEVW,ACEV,ACEVU,ACGLN,ACGLO,ACH,ACHC,ACHV,ACHR.WS,ACHR,ACHL,ACI,ACII,ACKIT,ACIU,ACIW,ACKIU,ACII.WS,ACII.U,ACKIW,ACIO,ACM,ACLS,ACNB,ACN,ACOR,ACP,ACMR,ACPpA,ACQR,ACRO,ACQRU,ACRO.WS,ACQRW,ACR,ACRO.U,ACRE,ACRS,ACST,ACRpD,ACRX,ACRpC,ACSI,ACT,ACTD,ACTDW,ACTG,ACTV,ACTDU,ACV,ACU,ACVFACVA,,ACXP,ACWF,ACWI,ACWV,ACY,ACWX,ADAG,ADALU,ADER,ADAP,ADBE,ADERU,ADCT,ADCpA,ADERW,ADC,ADEXADEX.U,,ADGI,ADFI,ADEX.WS,ADIL,ADES,ADI,ADIV,ADME,ADN,ADILW,ADNT,ADMA,ADM,ADMP,ADP,ADNWW,ADOC,ADOCR,ADOCW,ADRA,ADRA.U,ADPT,ADSADRA.WS,,ADRE,ADTADSK,,ADTN,ADUS,ADTX,ADVWW,ADV,AE,ADVMADXN,,ADX,ADXS,AEAC,AEACU,AEACW,AEE,AEAEU,AEFC,AEF,AEG,AEHA,AEHAU,AEHAW,AEHL,AEHR,AEI,AELpA,AEL,AEIS,AELpB,AEM,AEMB,AEMD,AEO,AENZ,AEP,AEPPL,AEPPZ,AER,AERC,AESE,AES
VPCC.WSVPG,,VPOP,VPL,VPN,VPU,VPV,VQS,VRAR,VRAI,VRA,VRAY,VRDN,VRCA,VRE,VREX,VRIG,VRME,VRMEW,VRM,VRNAVRNS,,VRP,VRNT,VRPXVRRM,,VRSK,VRS,VRSN,VRT,VRTSVRTV,,VS,VRTX,VSACU,VSAT,VSDAVSCO,,VSEC,VSGX,VSH,VSL,VSMV,VSLU,VSPYVSS,,VSSYW,VST,VSTA,VST.WS.A,VSTM,VSTO,VT,VTAQ,VTAQR,VTAQU,VTAQW,VTC,VTEB,VTEX,VTGN,VTHR,VTI,VTIP,VTIQ,VTIQU,VTIQW,VTN,VTOL,VTNR,VTR,VTSI,VTRS,VTV,VTRU,VTVT,VTWG,VTWO,VTWV,VUSB,VV,VUZI,VUG,VUSE,VTYX,VVI,VVNT,VVR,VVPR,VVOS,VVV,VWID,VWO,VWE,VWOB,VXFVXU ...

# %%
interesting_ticker_symbols[3079]
# Out:
# 'BBSI'

# %% [markdown]
# ### Save the database to disk to support good differential updates

# %%
if not data_pickle_read:
    pck = io.open("data_pickle.json", "w")
    pck.write(json.dumps(ticker_db))
    pck.close()
    
    pck = io.open("data_pickle.json.volatile", "w")
    pck.write(json.dumps(ticker_db))
    pck.close()

# %%
print(len(ticker_db))
print(len(interesting_ticker_symbols))
# Out:
# 11613
# 13614

# %%
ticker_db.keys()
# Out:
# dict_keys(['A', 'AA', 'AAA', 'AAAU', 'AAC', 'AAC.U', 'AAC.WS', 'AACG', 'AACI', 'AACIU', 'AACIW', 'AADI', 'AADR', 'AAIC', 'AAICpB', 'AAICpC', 'AAIN', 'AAL', 'AAMC', 'AAME', 'AAN', 'AAOI', 'AAON', 'AAP', 'AAPL', 'AAQC', 'AAQC.U', 'AAQC.WS', 'AAT', 'AATC', 'AAU', 'AAWW', 'AAXJ', 'AB', 'ABB', 'ABBV', 'ABC', 'ABCB', 'ABCL', 'ABCM', 'ABEO', 'ABEQ', 'ABEV', 'ABG', 'ABGI', 'ABIO', 'ABM', 'ABMD', 'ABNB', 'ABOS', 'ABR', 'ABRpD', 'ABRpE', 'ABRpF', 'ABSI', 'ABST', 'ABT', 'ABTX', 'ABUS', 'ABVC', 'AC', 'ACA', 'ACAD', 'ACAH', 'ACAHU', 'ACAHW', 'ACAQ', 'ACAQ.U', 'ACAQ.WS', 'ACB', 'ACBA', 'ACBAU', 'ACBAW', 'ACBI', 'ACC', 'ACCD', 'ACCO', 'ACDI.U', 'ACEL', 'ACER', 'ACES', 'ACET', 'ACEV', 'ACEVU', 'ACEVW', 'ACGL', 'ACGLN', 'ACGLO', 'ACH', 'ACHC', 'ACHL', 'ACHR', 'ACHR.WS', 'ACHV', 'ACI', 'ACII', 'ACII.U', 'ACII.WS', 'ACIO', 'ACIU', 'ACIW', 'ACKIT', 'ACKIU', 'ACKIW', 'ACLS', 'ACM', 'ACMR', 'ACN', 'ACNB', 'ACOR', 'ACP', 'ACPpA', 'ACQR', 'ACQRU', 'ACQRW', 'ACR', 'ACRE', 'ACRO', 'ACRO.U', 'ACRO.WS', 'ACRS', 'ACRX', 'ACRpC', 'ACRpD', 'ACSI', 'ACST', 'ACT', 'ACTD', 'ACTDU', 'ACTDW', 'ACTG', 'ACTV', 'ACU', 'ACV', 'ACVA', 'ACVF', 'ACWF', 'ACWI', 'ACWV', 'ACWX', 'ACXP', 'ACY', 'ADAG', 'ADALU', 'ADAP', 'ADBE', 'ADC', 'ADCT', 'ADCpA', 'ADER', 'ADERU', 'ADERW', 'ADES', 'ADEX', 'ADEX.U', 'ADEX.WS', 'ADFI', 'ADGI', 'ADI', 'ADIL', 'ADILW', 'ADIV', 'ADM', 'ADMA', 'ADME', 'ADMP', 'ADN', 'ADNT', 'ADNWW', 'ADOC', 'ADOCR', 'ADOCW', 'ADP', 'ADPT', 'ADRA', 'ADRA.U', 'ADRA.WS', 'ADRE', 'ADS', 'ADSK', 'ADT', 'ADTN', 'ADTX', 'ADUS', 'ADV', 'ADVM', 'ADVWW', 'ADX', 'ADXN', 'ADXS', 'AE', 'AEAC', 'AEACU', 'AEACW', 'AEAEU', 'AEE', 'AEF', 'AEFC', 'AEG', 'AEHA', 'AEHAU', 'AEHAW', 'AEHL', 'AEHR', 'AEI', 'AEIS', 'AEL', 'AELpA', 'AELpB', 'AEM', 'AEMB', 'AEMD', 'AENZ', 'AEO', 'AEP', 'AEPPL', 'AEPPZ', 'AER', 'AERC', 'AERI', 'AES', 'AESC', 'AESE', 'AESR', 'AEVA', 'AEVA.WS', 'AEY', 'AEYE', 'AEZS', 'AFACU', 'AFAQ', 'AFAQU', 'AFAQW', 'AFB', 'AFBI', 'AFCG', 'AFG', 'AFGB', 'AFGC', 'AFGD', 'AFGE', 'AFI', 'AFIB', 'AFIF', 'AFIN', 'AFINO', 'AFINP', 'AFK', 'AFL', 'AFLG', 'AFMC', 'AFMD', 'AFRM', 'AFSM', 'AFT', 'AFTR', 'AFTR.U', 'AFTR.WS', 'AFTY', 'AFYA', 'AG', 'AGAC', 'AGAC.U', 'AGAC.WS', 'AGBA', 'AGBAR', 'AGBAU', 'AGBAW', 'AGCB', 'AGCO', 'AGD', 'AGE', 'AGEN', 'AGFS', 'AGFY', 'AGG', 'AGGR', 'AGGRU', 'AGGRW', 'AGGY', 'AGI', 'AGIL', 'AGILW', 'AGIO', 'AGL', 'AGLE', 'AGM', 'AGM.A', 'AGMH', 'AGMpC', 'AGMpD', 'AGMpE', 'AGMpF', 'AGMpG', 'AGNC', 'AGNCM', 'AGNCN', 'AGNCO', 'AGNCP', 'AGNG', 'AGO', 'AGOV', 'AGOX', 'AGQ', 'AGR', 'AGRI', 'AGRIW', 'AGRO', 'AGRX', 'AGS', 'AGT', 'AGTC', 'AGTI', 'AGX', 'AGYS', 'AGZ', 'AGZD', 'AHCO', 'AHH', 'AHHX', 'AHHpA', 'AHI', 'AHLpC', 'AHLpD', 'AHLpE', 'AHPA', 'AHPAU', 'AHPAW', 'AHPI', 'AHT', 'AHTpD', 'AHTpF', 'AHTpG', 'AHTpH', 'AHTpI', 'AHYB', 'AI', 'AIA', 'AIC', 'AIEQ', 'AIF', 'AIG', 'AIGpA', 'AIH', 'AIHS', 'AIIQ', 'AIKI', 'AILG', 'AILV', 'AIM', 'AIMC', 'AIN', 'AINC', 'AINV', 'AIO', 'AIP', 'AIQ', 'AIR', 'AIRC', 'AIRG', 'AIRI', 'AIRR', 'AIRS', 'AIRT', 'AIRTP', 'AIT', 'AIV', 'AIZ', 'AIZN', 'AJG', 'AJRD', 'AJX', 'AJXA', 'AKA', 'AKAM', 'AKBA', 'AKIC', 'AKICU', 'AKICW', 'AKO.A', 'AKO.B', 'AKR', 'AKRO', 'AKTS', 'AKTX', 'AKU', 'AKUS', 'AKYA', 'AL', 'ALAC', 'ALACR', 'ALACU', 'ALACW', 'ALB', 'ALBO', 'ALC', 'ALCC', 'ALCO', 'ALDX', 'ALE', 'ALEC', 'ALEX', 'ALF', 'ALFA', 'ALFIW', 'ALG', 'ALGM', 'ALGN', 'ALGS', 'ALGT', 'ALHC', 'ALIM', 'ALINpA', 'ALINpB', 'ALINpE', 'ALIT', 'ALIT.WS', 'ALJJ', 'ALK', 'ALKS', 'ALKT', 'ALL', 'ALLE', 'ALLK', 'ALLO', 'ALLT', 'ALLY', 'ALLpB', 'ALLpG', 'ALLpH', 'ALLpI', 'ALNA', 'ALNY', 'ALORU', 'ALOT', 'ALPA', 'ALPAU', 'ALPAW', 'ALPN', 'ALPP', 'ALPpQ', 'ALRM', 'ALRN', 'ALRS', 'ALSN', 'ALT', 'ALTG', 'ALTGpA', 'ALTL', 'ALTM', 'ALTO', 'ALTR', 'ALTS', 'ALTU', 'ALTUU', 'ALTUW', 'ALTY', 'ALV', 'ALVR', 'ALX', 'ALXO', 'ALYA', 'ALZN', 'ALpA', 'AM', 'AMAL', 'AMAM', 'AMAO', 'AMAOU', 'AMAOW', 'AMAT', 'AMAX', 'AMBA', 'AMBC', 'AMBC.WS', 'AMBO', 'AMBP', 'AMBP.WS', 'AMC', 'AMCI', 'AMCIU', 'AMCIW', 'AMCR', 'AMCX', 'AMD', 'AME', 'AMED', 'AMEH', 'AMER', 'AMG', 'AMGN', 'AMH', 'AMH ...

# %% [markdown]
# ### Select interesting data

# %%
unique_times = []
for r in ticker_db['A']:
    if not r['t'] in unique_times:
        unique_times += [r['t']]
    else:
        print(r['t'])

print(ticker_db['A'][-1])
print(ticker_db['A'][-6])
# Out:
# {'v': 1403735.0, 'vw': 135.1972, 'o': 137.3, 'c': 135.71, 'h': 137.66, 'l': 133.7, 't': 1648180800000, 'n': 23527}
# {'v': 2766601.0, 'vw': 138.2767, 'o': 136.21, 'c': 139.12, 'h': 139.393, 'l': 136.21, 't': 1647576000000, 'n': 25832}

# %% [markdown]
# ### Convert into a Pandas dataframe, similar enough to the old one not to have to rebuild TR1007

# %%
all_ticker_dfs = []
gc.collect()
for t in ticker_db.keys():
    if ticker_db[t]:
        curdf = pd.DataFrame.from_dict(ticker_db[t], dtype=np.float64)
        curdf.set_index('t', inplace=True)        
        curdf = curdf.add_suffix('_{}'.format(t))
        curdf = curdf.rename(mapper={'vw_{}'.format(t): 'Close_{}'.format(t)},axis='columns')
        all_ticker_dfs += [curdf]

del ticker_db

# %%
all_ticker_dfs[0].describe()
# Out:
#                 v_A      Close_A          o_A          c_A          h_A  \
# count  4.655000e+03  4655.000000  4655.000000  4655.000000  4655.000000
# mean   3.474047e+06    45.415282    45.407828    45.417285    45.884363
# std    2.281332e+06    33.997465    34.016175    33.994478    34.317134
# min    2.816050e+05     9.002500     8.908900     8.894600     9.280700
# 25%    1.946922e+06    23.470400    23.487700    23.519950    23.798750
# 50%    2.975385e+06    31.944300    31.974800    31.982000    32.210800
# 75%    4.369309e+06    61.245600    61.265000    61.195000    61.620000
# max    3.114503e+07   179.021000   179.280000   179.280000   179.570000
#
#                l_A           n_A
# count  4655.000000   4655.000000
# mean     44.931101  15415.186037
# std      33.680805   9336.003842
# min       8.594300    918.000000
# 25%      23.137400   9584.000000
# 50%      31.631600  14568.000000
# 75%      60.760000  19886.000000
# max     177.170000  99980.000000

# %%
# join all collected DFs
gc.collect()
big_pickle = all_ticker_dfs[0].join(all_ticker_dfs[1:])

# free memory
#del all_ticker_dfs

# %%
# TODO: introduce a feature that captures this information instead
# TODO: evaluate backfill vs zero vs large, etc.
big_pickle = big_pickle.fillna(0)

# %%
big_pickle.index= pd.to_datetime(big_pickle.index, unit='ms')

# %%
big_pickle
# Out:
#                               v_A   Close_A       o_A       c_A       h_A  \
# t
# 2003-09-11 04:00:00  2.902657e+06   17.7711   17.5676   17.9036   18.0037
# 2003-10-01 04:00:00  3.337063e+06   15.9460   15.8373   15.9088   16.1018
# 2003-10-02 04:00:00  3.371608e+06   15.7329   15.8015   15.7228   15.8587
# 2003-10-03 04:00:00  5.526294e+06   16.4271   16.5165   16.4450   16.7810
# 2003-10-06 04:00:00  1.322517e+06   16.4885   16.4450   16.4665   16.6095
# ...                           ...       ...       ...       ...       ...
# 2022-03-21 04:00:00  1.285102e+06  138.0140  137.6300  138.1400  139.7900
# 2022-03-22 04:00:00  1.977714e+06  138.9244  138.0100  139.2900  140.1997
# 2022-03-23 04:00:00  1.337390e+06  134.7575  137.8500  134.1800  137.9550
# 2022-03-24 04:00:00  1.346742e+06  135.3507  134.8900  136.4100  136.5800
# 2022-03-25 04:00:00  1.403735e+06  135.1972  137.3000  135.7100  137.6600
#
#                           l_A      n_A          v_AA  Close_AA   o_AA  ...  \
# t                                                                      ...
# 2003-09-11 04:00:00   17.4817   1907.0  1.217700e+06   84.7560  85.20  ...
# 2003-10-01 04:00:00   15.7586   1940.0  2.736200e+06   79.7100  78.90  ...
# 2003-10-02 04:00:00   15.6156   2192.0  1.260133e+06   81.3612  80.64  ...
# 2003-10-03 04:00:00   15.8873   2341.0  2.238600e+06   84.2301  81.39  ...
# 2003-10-06 04:00:00   16.3092   1680.0  1.108533e+06   85.0908  85.44  ...
# ...                       ...      ...           ...       ...    ...  ...
# 2022-03-21 04:00:00  137.0100  26403.0  9.901007e+06   90.1853  85.57  ...
# 2022-03-22 04:00:00  137.6500  25031.0  6.100540e+06   89.7857  89.98  ...
# 2022-03-23 04:00:00  133.4482  24941.0  6.848035e+06   93.9962  91.49  ...
# 2022-03-24 04:00:00  133.5900  17127.0  7.323274e+06   93.5575  91.65  ...
# 2022-03-25 04:00:00  133.7000  23527.0  6.039451e+06   93.0578  95.89  ...
#
#                      h_ZYNE  l_ZYNE  n_ZYNE    v_ZYXI  Close_ZYXI  o_ZYXI  \
# t
# 2003-09-11 04:00:00  0.0000  0.0000     0.0       0.0      0.0000    0.00
# 2003-10-01 04:00:00  0.0000  0.0000     0.0       0.0      0.0000    0.00
# 2003-10-02 04:00:00  0.0000  0.0000     0.0       0.0      0.0000    0.00
# 2003-10-03 04:00:00  0.0000  0.0000     0.0       0.0      0.0000    0.00
# 2003-10-06 04:00:00  0.0000  0.0000     0.0       0.0      0.0000    0.00
# ...                     ...     ...     ...       ...         ...     ...
# 2022-03-21 04:00:00  2.0600  1.9400  2310.0  299396.0      5.7722    5.78
# 2022-03-22 04:00:00  2.0950  1.9101  2242.0  346504.0      5.9702    5.83
# 2022-03-23 04:00:00  2.1100  1.9900  2593.0  517600.0      6.2789    5.98
# 2022-03-24 04:00:00  2.1200  1.9900  3544.0  344834.0      6.2927    6.26
# 2022-03-25 04:00:00  2.2399  2.0600  5277.0  346764.0      6.3189    6.36
#
#                      c_ZYXI  h_ZYXI  l_ZYXI  n_ZYXI
# t
# 2003-09-11 04:00:00    0.00   0.000    0.00     0.0
# 2003-10-01 04:00:00    0.00   0.000    0.00     0.0
# 2003-10-02 04:00:00    0.00   0.000    0.00     0.0
# 2003-10-03 04:00:00    0.00   0.000    0.00     0.0
# 2003-10-06 04:00:00    0.00   0.000    0.00     0.0
# ...                     ...     ...     ...     ...
# 2022-03-21 04:00:00    5.78   5.965    5.64  4342.0
# 2022-03-22 04:00:00    5.98   6.120    5.83  3970.0
# 2022-03-23 04:00:00    6.25   6.520    5.91  5602.0
# 2022-03-24 04:00:00    6.36   6.410    6.14  4337.0
# 2022-03-25 04:00:00    6.32   6.470    6.19  4866.0
#
# [4655 rows x 81291 columns]

# %% [markdown]
# ### Final result pickled to provide to TR1007

# %%
big_pickle.to_pickle("BIG.pickle")

# %%
i = 0
for v in big_pickle['Close_WOOD']:
    if v > 0:
        break
    i+=1
i

big_pickle['Close_WOOD'][i:]
# Out:
# t
# 2008-06-25 04:00:00    48.9286
# 2008-06-26 04:00:00    47.6243
# 2008-06-27 04:00:00    47.3764
# 2008-06-30 04:00:00    47.3000
# 2008-07-01 04:00:00    46.5432
#                         ...
# 2022-03-21 04:00:00    91.8730
# 2022-03-22 04:00:00    91.6823
# 2022-03-23 04:00:00    90.6818
# 2022-03-24 04:00:00    90.5545
# 2022-03-25 04:00:00    90.3678
# Name: Close_WOOD, Length: 3463, dtype: float64
